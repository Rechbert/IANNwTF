# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
x = np.random.random_sample(size=100)
t = np.empty(100)
for i in range(100):
    t[i] = x[i]**3-x[i]**2
# Out:
# -0.001983929416641052

# %%
plt.plot(t,x)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
class Layer:
    n_units = 0
    input_units = 0
    bias_vector = 0
    weight_matrix = 0
    layer_input = 0
    layer_preactivation = 0
    layer_activation = 0
    def __init__(self, n_units, input_units, layer_input):
        self.layer_input = np.append(layer_input, 1)
        self.n_units = n_units
        self.input_units = input_units
        self.bias_vector = np.zeros(shape=n_units)
        self.weight_matrix = np.r_[np.random.uniform(low=-10, high=10, size=(input_units, n_units) ), [self.bias_vector]]
        self.layer_preactivation = np.zeros(shape=n_units)
        self.layer_activation = np.zeros(shape=n_units)
    def forward_step(self):
        self.layer_preactivation = np.dot(self.layer_input, self.weight_matrix)
        for i in range(self.n_units):
            if self.layer_preactivation[i] > 0:
                self.layer_activation[i] = self.layer_preactivation[i]
            else:
                self.layer_activation[i] = 0
        return self.layer_activation
        
    def backward_step(self):

# %%
data_a = [3.5, 2, 6.5]
layer1 = Layer(2,3,data_a)
print(layer1.forward_step())
# Out:
# [ 0.         52.88874603]
